# %%
from kneeassist.config import SAMPLE_DATA_DIR
from kneeassist.data.explorer import MRIExplorer

# %%
explorer = MRIExplorer()

explorer.load(SAMPLE_DATA_DIR / "0060.npy")

# %%
explorer.summary()
# Out:
# ...
# MRI SUMMARY
# ...
# File Name           : 0060.npy
# Shape               : (18, 256, 256)
# Data Type           : uint8
# Minimum Pixel Value : 0
# Maximum Pixel Value : 255
# Mean Pixel Value    : 62.37
# Std Pixel Value     : 48.95
# Number of Slices    : 18
# ...

# %%
explorer.show_middle_slice()

# %%
explorer.show_multiple_slices()

# %%
explorer.pixel_histogram()

# %%
explorer.slice_dimensions()
# Out:
# Height : 256
# Width  : 256
