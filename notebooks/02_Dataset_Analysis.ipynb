# %%
import importlib
import kneeassist.data.dataset_explorer as dataset_explorer

importlib.reload(dataset_explorer)

explorer = dataset_explorer.DatasetExplorer()

# %%
from kneeassist.config import SAMPLE_DATA_DIR

slice_counts = explorer.analyze_slice_distribution(
    SAMPLE_DATA_DIR
)

explorer.plot_slice_distribution(slice_counts)
# Out:
# ...
# MRI SLICE STATISTICS
# ...
# Number of MRIs : 1
# Minimum Slices : 18
# Maximum Slices : 18
# Average Slices : 18.00
# Median Slices  : 18.0
# ...
